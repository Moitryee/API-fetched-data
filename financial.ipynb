# %% [markdown]
# ## Fetching data from the API
# ### this data is belong to financial stocks.
# **This data returns intraday time series (timestamp, open, high,close , low ,volume) in 26 january 2024
#
# *** I have taken data from rapid API website

# %%
##importing importent libraries
import json 
import pandas as pd

# %%
import requests

url = "https://alpha-vantage.p.rapidapi.com/query"

querystring = {"interval":"5min","function":"TIME_SERIES_INTRADAY","symbol":"MSFT","datatype":"json","output_size":"compact"}

headers = {
	"X-RapidAPI-Key": "e0f8c01ed7msh7e7cf0b184bf554p1326d0jsna1817da82c14",
	"X-RapidAPI-Host": "alpha-vantage.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)
data = response.json()


print(response.json())
# Out:
# {'Meta Data': {'1. Information': 'Intraday (5min) open, high, low, close prices and volume', '2. Symbol': 'MSFT', '3. Last Refreshed': '2024-01-30 19:55:00', '4. Interval': '5min', '5. Output Size': 'Compact', '6. Time Zone': 'US/Eastern'}, 'Time Series (5min)': {'2024-01-30 19:55:00': {'1. open': '406.5100', '2. high': '407.6500', '3. low': '404.6590', '4. close': '407.2600', '5. volume': '50684'}, '2024-01-30 19:50:00': {'1. open': '406.9000', '2. high': '407.2700', '3. low': '406.1000', '4. close': '406.4800', '5. volume': '17100'}, '2024-01-30 19:45:00': {'1. open': '406.1000', '2. high': '407.2000', '3. low': '406.0000', '4. close': '406.8750', '5. volume': '11365'}, '2024-01-30 19:40:00': {'1. open': '405.6700', '2. high': '406.1000', '3. low': '405.6000', '4. close': '406.1000', '5. volume': '8929'}, '2024-01-30 19:35:00': {'1. open': '405.5000', '2. high': '406.4000', '3. low': '405.2600', '4. close': '405.7000', '5. volume': '12831'}, '2024-01-30 19:30:00': {'1. open': '405.
# ...

# %%
type(data)
# Out:
# dict

# %% [markdown]
# #### understanding the data
# ###### data have two important feature
# 1. Meta data : description of the data
# 2. Time Series data (which contains the main data)

# %% [markdown]
# ### Description of the data
# 1. OpenPrice : The opening price for a stock is the price it trades immediately after the stock market opens
# 2. close price :The closing price is the last price at which a security traded during the regular trading day.
# 3. low price: lowest price reported in troughout the day
# 4. high price : highest price reported in throughout the day
# 5. volume : total stocks sells on that specific time and date

# %%
for i in data.items():
    print(i[0])
# Out:
# Meta Data
# Time Series (5min)

# %%
for i in data.items():
    print(i[1])
# Out:
# {'1. Information': 'Intraday (5min) open, high, low, close prices and volume', '2. Symbol': 'MSFT', '3. Last Refreshed': '2024-01-30 19:55:00', '4. Interval': '5min', '5. Output Size': 'Compact', '6. Time Zone': 'US/Eastern'}
# ...

# %%
## copying only the time series data 
df={'2024-01-26 19:55:00': {'1. open': '404.1000', '2. high': '404.1500', '3. low': '404.0000', '4. close': '404.0300', '5. volume': '1549'}, '2024-01-26 19:50:00': {'1. open': '403.9500', '2. high': '404.1000', '3. low': '403.9100', '4. close': '404.0050', '5. volume': '552'}, '2024-01-26 19:45:00': {'1. open': '404.0000', '2. high': '404.0300', '3. low': '403.9500', '4. close': '403.9600', '5. volume': '1313'}, '2024-01-26 19:40:00': {'1. open': '404.0200', '2. high': '404.1000', '3. low': '403.9000', '4. close': '404.0000', '5. volume': '892'}, '2024-01-26 19:35:00': {'1. open': '404.0200', '2. high': '404.1500', '3. low': '403.9500', '4. close': '404.0200', '5. volume': '243'}, '2024-01-26 19:30:00': {'1. open': '404.0200', '2. high': '404.1500', '3. low': '404.0200', '4. close': '404.0500', '5. volume': '628'}, '2024-01-26 19:25:00': {'1. open': '404.0700', '2. high': '404.1300', '3. low': '404.0100', '4. close': '404.0200', '5. volume': '302'}, '2024-01-26
1. open': '405.9200', '2. high': '406.0500', '3. low': '405.3600', '4. close': '405.3920', '5. volume': '124774'}, '2024-01-26 12:15:00': {'1. open': '405.7900', '2. high': '405.9300', '3. low': '405.7200', '4. close': '405.9100', '5. volume': '90203'}, '2024-01-26 12:10:00': {'1. open': '405.5820', '2. high': '405.9300', '3. low': '405.3400', '4. close': '405.7960', '5. volume': '109599'}, '2024-01-26 12:05:00': {'1. open': '405.9450', '2. high': '406.1700', '3. low': '405.5100', '4. close': '405.6000', '5. volume': '128045'}, '2024-01-26 12:00:00': {'1. open': '405.6800', '2. high': '405.9600', '3. low': '405.5400', '4. close': '405.9350', '5. volume': '107289'}, '2024-01-26 11:55:00': {'1. open': '405.6250', '2. high': '406.0100', '3. low': '405.5700', '4. close': '405.6700', '5. volume': '171398'}, '2024-01-26 11:50:00': {'1. open': '405.5400', '2. high': '405.7900', '3. low': '405.4500', '4. close': '405.6300', '5. volume': '157393'}, '2024-01-26 11:45:00': {'1. open': '404.7900', '2. high': '405.5510', '3. low': '404.5900', '4. close': '405.5510', '5. volume': '138330'}, '2024-01-26 11:40:00': {'1. open': '404.7600', '2. high': '404.8300', '3. low': '404.4480', '4. close': '404.7950', '5. volume': '177353'}}

# %%
type(df)
# Out:
# dict

# %% [markdown]
# ** making list of the each column and at last appending it to form the dataframe

# %%
open_values = [value.get('1. open', None) for value in df.values()]
#print(open_values)

# %%
high_values = [value.get('2. high', None) for value in df.values()]
#print(high_values)

# %%
low_values = [value.get('3. low', None) for value in df.values()]
#print(low_values)

# %%
close_values = [value.get('4. close', None) for value in df.values()]
#print(close_values)

# %%
volume_values = [value.get('5. volume', None) for value in df.values()]
#print(volume_values)

# %%
keys = []
for key in df:
    keys.append(key)
#print(keys)

len(keys)
# Out:
# 100

# %%
data = {'timestamp': keys, 'OpenPrice': open_values, 'HighPrice': high_values, "LowPrice": low_values,"ClosePrice": close_values,"Volume": volume_values}
df = pd.DataFrame(data)
df
# Out:
#               timestamp OpenPrice HighPrice  LowPrice ClosePrice  Volume
# 0   2024-01-26 19:55:00  404.1000  404.1500  404.0000   404.0300    1549
# 1   2024-01-26 19:50:00  403.9500  404.1000  403.9100   404.0050     552
# 2   2024-01-26 19:45:00  404.0000  404.0300  403.9500   403.9600    1313
# 3   2024-01-26 19:40:00  404.0200  404.1000  403.9000   404.0000     892
# 4   2024-01-26 19:35:00  404.0200  404.1500  403.9500   404.0200     243
# ..                  ...       ...       ...       ...        ...     ...
# 95  2024-01-26 12:00:00  405.6800  405.9600  405.5400   405.9350  107289
# 96  2024-01-26 11:55:00  405.6250  406.0100  405.5700   405.6700  171398
# 97  2024-01-26 11:50:00  405.5400  405.7900  405.4500   405.6300  157393
# 98  2024-01-26 11:45:00  404.7900  405.5510  404.5900   405.5510  138330
# 99  2024-01-26 11:40:00  404.7600  404.8300  404.4480   404.7950  177353
#
# [100 rows x 6 columns]

# %%
df.to_csv("financial_data.csv")
